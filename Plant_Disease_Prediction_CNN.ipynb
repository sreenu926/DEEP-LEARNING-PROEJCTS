# %% [markdown]
# # **Plant Disease Prediction_CNN**

# %%
# !pip install Pillow==4.0.0
# !pip install PIL
# !pip install image

# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')

import os
os.getcwd()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Pillow==4.0.0
#   Using cached Pillow-4.0.0-cp37-cp37m-linux_x86_64.whl
# Requirement already satisfied: olefile in /usr/local/lib/python3.7/dist-packages (from Pillow==4.0.0) (0.46)
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.1.1
#     Uninstalling Pillow-9.1.1:
#       Successfully uninstalled Pillow-9.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.12.0+cu113 requires pillow!=8.3.*,>=5.3.0, but you have pillow 4.0.0 which is incompatible.
# scikit-image 0.18.3 requires pillow!=7.1.0,!=7.1.1,>=4.3.0, but you have pillow 4.0.0 which is incompatible.
# pytesseract 0.3.9 requires Pillow>=8.0.0, but you have pillow 4.0.0 which is incompatible.
# bokeh 2.3.3 requires pillow>=7.1.0, but you have pillow 4.0.0 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed Pillow-4.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement PIL (from versions: none)
# ERROR: No matching distribution found for PIL
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: image in /usr/local/lib/python3.7/dist-packages (1.5.33)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from image) (4.0.0)
# Requirement already satisfied: django in /usr/local/lib/python3.7/dist-packages (from image) (3.2.13)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from image) (1.15.0)
# Requirement already satisfied: asgiref<4,>=3.3.2 in /usr/local/lib/python3.7/dist-packages (from django->image) (3.5.2)
# Requirement already satisfied: sqlparse>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from django->image) (0.4.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from django->image) (2022.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from asgiref<4,>=3.3.2->django->image) (4.2.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.7/dist-packages (from pillow->image) (0.46)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '/content'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
import os
from os import listdir
import PIL
from PIL import Image
from sklearn.preprocessing import label_binarize,  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from tensorflow.keras.optimizers import Adam
#from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split
from keras.models import model_from_json
from tensorflow.keras.utils import to_categorical
#from keras.utils import to_categorical

# %%
# Plotting 12 images to check dataset
# !pip install pytesseract
# !pip install PIL
# !pip install image
# %matplotlib inline

plt.figure(figsize=(12,12))
path = "/content/drive/My Drive/Content/Plant_images/Potato___Early_blight"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(os.listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)#width of image
    plt.ylabel(rand_img.shape[0], fontsize = 10)#height of image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.7/dist-packages (0.3.9)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.7/dist-packages (from pytesseract) (21.3)
# Collecting Pillow>=8.0.0
#   Using cached Pillow-9.1.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=21.3->pytesseract) (3.0.9)
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 4.0.0
#     Uninstalling Pillow-4.0.0:
#       Successfully uninstalled Pillow-4.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed Pillow-9.1.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement PIL (from versions: none)
# ERROR: No matching distribution found for PIL
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: image in /usr/local/lib/python3.7/dist-packages (1.5.33)
# Requirement already satisfied: django in /usr/local/lib/python3.7/dist-packages (from image) (3.2.13)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from image) (1.15.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from image) (9.1.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from django->image) (2022.1)
# Requirement already satisfied: sqlparse>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from django->image) (0.4.2)
# Requirement already satisfied: asgiref<4,>=3.3.2 in /usr/local/lib/python3.7/dist-packages (from django->image) (3.5.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from asgiref<4,>=3.3.2->django->image) (4.2.0)

# %%
#Converting Images to array 
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, (256,256))  
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
dir = "/content/drive/My Drive/Content/Plant_images"
root_dir = listdir(dir)
image_list, label_list = [], []
all_labels = ['Corn-Common_rust', 'Potato-Early_blight', 'Tomato-Bacterial_spot']
binary_labels = [0,1,2]
temp = -1

# Reading and converting image to numpy array
for directory in root_dir:
  plant_image_list = listdir(f"{dir}/{directory}")
  temp += 1
  for files in plant_image_list:
    image_path = f"{dir}/{directory}/{files}"
    image_list.append(convert_image_to_array(image_path))
    label_list.append(binary_labels[temp])

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts.head()
# Out:
# 0    300
# 1    300
# 2    300
# dtype: int64

# %%
image_list[0].shape
# Out:
# (256, 256, 3)

# %%
label_list = np.array(label_list)
label_list.shape
# Out:
# (900,)

# %%
# Split the Data

x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %%
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 256,256,3)
x_test = x_test.reshape( -1, 256,256,3)

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding="same",input_shape=(256,256,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(8, activation="relu"))
model.add(Dense(3, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 85, 85, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 85, 85, 16)        4624
#
#  max_pooling2d_1 (MaxPooling  (None, 42, 42, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 28224)             0
#
#  dense (Dense)               (None, 8)                 225800
#
#  dense_1 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 231,347
# Trainable params: 231,347
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, 
                    validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 46s 8s/step - loss: 1.0759 - accuracy: 0.3802 - val_loss: 1.0429 - val_accuracy: 0.4375
# Epoch 2/50
# 5/5 [==============================] - 27s 5s/step - loss: 1.0225 - accuracy: 0.5122 - val_loss: 0.9925 - val_accuracy: 0.6875
# Epoch 3/50
# 5/5 [==============================] - 29s 6s/step - loss: 0.9708 - accuracy: 0.7639 - val_loss: 0.9387 - val_accuracy: 0.8194
# Epoch 4/50
# 5/5 [==============================] - 29s 6s/step - loss: 0.9119 - accuracy: 0.8299 - val_loss: 0.8903 - val_accuracy: 0.8889
# Epoch 5/50
# 5/5 [==============================] - 26s 5s/step - loss: 0.8543 - accuracy: 0.8767 - val_loss: 0.8280 - val_accuracy: 0.9097
# Epoch 6/50
# 5/5 [==============================] - 26s 5s/step - loss: 0.7874 - accuracy: 0.9184 - val_loss: 0.7661 - val_accuracy: 0.9167
# Epoch 7/50
# 5/5 [==============================] - 26s 5s/step - loss: 0.7165 - accuracy: 0.9410 - val_loss: 0.6953 - val_accuracy: 0.9236
# Epoch 8/50
# 5/5 [==============================] - 26s 5s/step - loss: 0.6430 - accuracy: 0.9531 - val_loss: 0.6240 - val_accuracy: 0.9236
# Epoch 9/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.5685 - accuracy: 0.9601 - val_loss: 0.5546 - val_accuracy: 0.9236
# Epoch 10/50
# 5/5 [==============================] - 26s 5s/step - loss: 0.4970 - accuracy: 0.9583 - val_loss: 0.4880 - val_accuracy: 0.9375
# Epoch 11/50
# 5/5 [==============================] - 26s 5s/step - loss: 0.4298 - accuracy: 0.9740 - val_loss: 0.4259 - val_accuracy: 0.9375
# Epoch 12/50
# 5/5 [==============================] - 29s 6s/step - loss: 0.3654 - accuracy: 0.9774 - val_loss: 0.3700 - val_accuracy: 0.9375
# Epoch 13/50
# 5/5 [==============================] - 26s 5s/step - loss: 0.3070 - accuracy: 0.9792 - val_loss: 0.3185 - val_accuracy: 0.9444
# Epoch 14/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.2582 - accuracy: 0.9809 - val_loss: 0.2728 - val_accuracy: 0.9514
# Epoch 15/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.2151 - accuracy: 0.9826 - val_loss: 0.2312 - val_accuracy: 0.9583
# Epoch 16/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.1801 - accuracy: 0.9878 - val_loss: 0.1983 - val_accuracy: 0.9514
# Epoch 17/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.1513 - accuracy: 0.9896 - val_loss: 0.1746 - val_accuracy: 0.9653
# Epoch 18/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.1284 - accuracy: 0.9931 - val_loss: 0.1525 - val_accuracy: 0.9583
# Epoch 19/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.1109 - accuracy: 0.9931 - val_loss: 0.1362 - val_accuracy: 0.9583
# Epoch 20/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0980 - accuracy: 0.9913 - val_loss: 0.1270 - val_accuracy: 0.9653
# Epoch 21/50
# 5/5 [==============================] - 29s 6s/step - loss: 0.0871 - accuracy: 0.9931 - val_loss: 0.1162 - val_accuracy: 0.9583
# Epoch 22/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0769 - accuracy: 0.9931 - val_loss: 0.1078 - val_accuracy: 0.9583
# Epoch 23/50
# 5/5 [==============================] - 30s 6s/step - loss: 0.0680 - accuracy: 0.9931 - val_loss: 0.1076 - val_accuracy: 0.9722
# Epoch 24/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0601 - accuracy: 0.9931 - val_loss: 0.0951 - val_accuracy: 0.9583
# Epoch 25/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0555 - accuracy: 0.9948 - val_loss: 0.0957 - val_accuracy: 0.9653
# Epoch 26/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0541 - accuracy: 0.9931 - val_loss: 0.0885 - val_accuracy: 0.9722
# Epoch 27/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0487 - accuracy: 0.9948 - val_loss: 0.0828 - val_accuracy: 0.9653
# Epoch 28/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0417 - accuracy: 0.9931 - val_loss: 0.0884 - val_accuracy: 0.9722
# Epoch 29/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0402 - accuracy: 0.9948 - val_loss: 0.0782 - val_accuracy: 0.9722
# Epoch 30/50
# 5/5 [==============================] - 29s 6s/step - loss: 0.0371 - accuracy: 0.9965 - val_loss: 0.0760 - val_accuracy: 0.9722
# Epoch 31/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0336 - accuracy: 0.9965 - val_loss: 0.0785 - val_accuracy: 0.9653
# Epoch 32/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0321 - accuracy: 0.9965 - val_loss: 0.0741 - val_accuracy: 0.9722
# Epoch 33/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0295 - accuracy: 0.9965 - val_loss: 0.0708 - val_accuracy: 0.9722
# Epoch 34/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0275 - accuracy: 0.9965 - val_loss: 0.0728 - val_accuracy: 0.9722
# Epoch 35/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0260 - accuracy: 0.9983 - val_loss: 0.0688 - val_accuracy: 0.9792
# Epoch 36/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0244 - accuracy: 0.9965 - val_loss: 0.0659 - val_accuracy: 0.9722
# Epoch 37/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0230 - accuracy: 0.9965 - val_loss: 0.0699 - val_accuracy: 0.9722
# Epoch 38/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0217 - accuracy: 0.9983 - val_loss: 0.0664 - val_accuracy: 0.9792
# Epoch 39/50
# 5/5 [==============================] - 29s 6s/step - loss: 0.0210 - accuracy: 0.9965 - val_loss: 0.0629 - val_accuracy: 0.9861
# Epoch 40/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.0699 - val_accuracy: 0.9722
# Epoch 41/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0191 - accuracy: 0.9983 - val_loss: 0.0662 - val_accuracy: 0.9722
# Epoch 42/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0176 - accuracy: 0.9983 - val_loss: 0.0648 - val_accuracy: 0.9792
# Epoch 43/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0166 - accuracy: 0.9983 - val_loss: 0.0636 - val_accuracy: 0.9792
# Epoch 44/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0166 - accuracy: 0.9983 - val_loss: 0.0623 - val_accuracy: 0.9792
# Epoch 45/50
# 5/5 [==============================] - 29s 6s/step - loss: 0.0157 - accuracy: 0.9983 - val_loss: 0.0648 - val_accuracy: 0.9722
# Epoch 46/50
# 5/5 [==============================] - 29s 5s/step - loss: 0.0147 - accuracy: 0.9983 - val_loss: 0.0583 - val_accuracy: 0.9861
# Epoch 47/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9722
# Epoch 48/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0134 - accuracy: 0.9983 - val_loss: 0.0615 - val_accuracy: 0.9792
# Epoch 49/50
# 5/5 [==============================] - 29s 6s/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.0571 - val_accuracy: 0.9861
# Epoch 50/50
# 5/5 [==============================] - 27s 5s/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.0677 - val_accuracy: 0.9792

# %%
model.save("/content/drive/My Drive/Content/plant_disease.h5")
# serialize model to json
json_model = model.to_json()
#save the model architecture to JSON file
with open('/content/drive/My Drive/Content/plant_model.json', 'w') as json_file:
    json_file.write(json_model)
#saving the weights of the model
model.save_weights('/content/drive/My Drive/Content/plant_model_weights.h5')

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 6/6 [==============================] - 3s 419ms/step - loss: 0.1003 - accuracy: 0.9833
# Test Accuracy: 98.33333492279053

# %%
y_pred = model.predict(x_test)

# %%
# Plotting image to compare
img = array_to_img(x_test[10])
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",all_labels[np.argmax(y_test[10])])
print("Predicted : ",all_labels[np.argmax(y_pred[10])])
# Out:
# Originally :  Potato-Early_blight
# Predicted :  Potato-Early_blight
